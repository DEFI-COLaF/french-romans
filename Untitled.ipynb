# %%
import pandas as pd
import seaborn as sns


df = pd.read_csv("qc2.csv", index_col=0)
sns.lineplot(data=df[df.author=="zola"].sort_values(["gap", "year"]), y="candt", x="year", hue="gap")
df[df.candt > 0][["author", "candt"]].sort_values("candt").drop_duplicates("author")
# Out:
#      author  candt
# 700     sue     14
# 302  balzac     29
# 242   dumas     29
# 738   verne     32
# 377    sand     39
# 341    zola     47
